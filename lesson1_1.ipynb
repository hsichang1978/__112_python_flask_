# %%
print("hello python?")
# Out:
# hello python?
# Bad pipe message: %s [b'\xdf\xa3y|\xe4(v\xd4Z\xca\x96Q1\x95\xc5]\xe7\xd7 \xb3\x86\xb4\x19G\x00\xc6I\x1e\xc0\xb5\xbcY\x05\x9d\x8a|\x89\xa6 \x1f\xfa)\x17\x9f\xcd\xc3\xa9:\x12\x17K\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00']
# Bad pipe message: %s [b"\xac\x82'\t\n\xbc{\x9b\x12%0\x8d\xea\x8c\x96>A?\xd6\x85\xfe\xd02\xe4\xc0\xc8;\xc6P\x1bo"]
# ...

# %%
#註解
print(123,"我是int")
print(456.123,'我是float')
print('字串',"我是srt")
print(True,"我是bool值")
print('___________________')
# Out:
# 123 我是int
# 456.123 我是float
# 字串 我是srt
# True 我是bool值
# ___________________
