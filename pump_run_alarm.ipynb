# %%
import time

# 初始化按键计数器和上次按键时间
button_count = 0
last_press_time = time.time()

# 定义警报触发阈值和时间限制（10分钟）
alarm_threshold = 2
time_limit = 10 * 60

# 模拟按键按下的函数
def button_pressed():
    global button_count, last_press_time
    button_count += 1
    last_press_time = time.time()

# 主循环
while True:
    # 检查按键是否按下
    if button_is_pressed():
        button_pressed()
        
    # 检查时间是否超过限制
    elapsed_time = time.time() - last_press_time
    if elapsed_time >= time_limit:
        # 重置计数器和时间
        button_count = 0
        last_press_time = time.time()
    
    # 检查是否触发警报
    if button_count >= alarm_threshold:
        print("警报触发！")
        # 在此处添加触发警报的相关代码
        
    # 可以添加适当的延迟，以减少循环频率
    time.sleep(0.1)

# %%
import time
seconds = time.time()
print (seconds)

# %%
import time

# 设置时间间隔（以秒为单位）
interval = 10 * 60

# 初始化计时器和计数器
start_time = time.time()
button_press_count = 0

while True:
    # 检测按钮是否按下
    button_pressed = 8  # 通过适当的方式检测按钮状态，这里用一个占位符表示
    
    if button_pressed:
        # 按钮按下，增加计数器
        button_press_count += 1

        # 如果计数器达到2次以上，跳出警报并重置计时器和计数器
        if button_press_count >= 2:
            print("警报！按钮在10分钟内被按下2次以上！")
            # 触发警报操作，例如发送通知或执行其他必要的操作

            # 重置计时器和计数器
            start_time = time.time()
            button_press_count = 0
    
    # 检查时间间隔是否已过去
    elapsed_time = time.time() - start_time
    if elapsed_time >= interval:
        # 时间间隔已过去，重置计时器和计数器
        start_time = time.time()
        button_press_count = 0

# %%
import time

# 设置时间间隔（以秒为单位）
interval = 10 * 60

# 初始化计时器和计数器
start_time = time.time()
button_press_count = 0

while True:
    # 检测按钮是否按下
    button_pressed = 1  # 通过适当的方式检测按钮状态，这里用一个占位符表示
    
    if button_pressed:
        # 按钮按下，增加计数器
        button_press_count += 1

        # 如果计数器达到2次以上，跳出警报并重置计时器和计数器
        if button_press_count >= 2:
            print("警报！按钮在10分钟内被按下2次以上！")
            # 触发警报操作，例如发送通知或执行其他必要的操作

            # 重置计时器和计数器
            start_time = time.time()
            button_press_count = 0
    
    # 检查时间间隔是否已过去
    elapsed_time = time.time() - start_time
    if elapsed_time >= interval:
        # 时间间隔已过去，重置计时器和计数器
        start_time = time.time()
        button_press_count = 0

# %%
import time

# 设置时间间隔（以秒为单位）
interval = 10 * 60

# 初始化计时器和计数器
start_time = time.time()
button_press_count = 0

while True:
    # 检测按钮是否按下
    button_pressed = # 通过适当的方式检测按钮状态，这里用一个占位符表示
    
    if button_pressed:
        # 按钮按下，增加计数器
        button_press_count += 1

        # 如果计数器达到2次以上，跳出警报并重置计时器和计数器
        if button_press_count >= 2:
            print("警报！按钮在10分钟内被按下2次以上！")
            # 触发警报操作，例如发送通知或执行其他必要的操作

            # 重置计时器和计数器
            start_time = time.time()
            button_press_count = 0
    
    # 检查时间间隔是否已过去
    elapsed_time = time.time() - start_time
    if elapsed_time >= interval:
        # 时间间隔已过去，重置计时器和计数器
        start_time = time.time()
        button_press_count = 0
